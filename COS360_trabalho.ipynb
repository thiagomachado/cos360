# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagomachado/cos360/blob/main/COS360_trabalho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Funções

# %%
def f(x, y):
    return x ** 2 + (np.exp(x)- y) ** 2

def plotFunction():
  x = np.linspace(-1, 1, 30)
  y = np.linspace(0, 3, 30)

  X, Y = np.meshgrid(x, y)
  Z = f(X, Y)

  fig = plt.figure(clear=True, figsize=(14, 7))
  ax = plt.axes(projection='3d')
  dplot = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                  cmap='viridis', edgecolor='none')
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_zlabel('z')
  plt.colorbar(dplot, shrink=0.5, aspect=10)

# %% [markdown]
# # Análise da Função
# O nosso problema consiste em minimizar a função:
#
# \begin{equation}
#  f(x_1, x_2) = x_1^2 + ({e}^{x_1} - x_2)^2
# \end{equation}
#
# Sendo seu domínio:
# \begin{equation}
# \Omega = \mathbb{R}^2
# \end{equation}

# %%
#@title Gráfico da Função Objetivo {display-mode: "form"}
plotFunction()
